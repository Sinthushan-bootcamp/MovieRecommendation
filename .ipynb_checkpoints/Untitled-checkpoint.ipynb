# %%
import pandas as pd

# %%
ratings_df = pd.read_csv('Data/ratings_small.csv')

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
movies_df = pd.read_csv('Data/movies_metadata.csv')
# Out:
# C:\Users\sinth\anaconda3\envs\pyvizenv\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
#Dropping columns that are deemed unusable for recommender
movies_df.drop(columns=[
            'belongs_to_collection',
            'homepage','imdb_id', 
            'original_title', 
            'overview', 
            'spoken_languages', 
            'status', 'tagline', 
            'poster_path',
            'video'
        ], inplace = True)

# %%
from ast import literal_eval
production_countries = []
production_companies = []
for index, row in movies_df.iterrows():
    try:
        production_countries.append(literal_eval(movies_df['production_countries'][index])[0]['name'])
    except:
        production_countries.append(None)
    try:
        production_companies.append(literal_eval(movies_df['production_companies'][index])[0]['name'])
    except:
        production_companies.append(None) 
movies_df['production_countries'] = production_countries
movies_df['production_companies'] = production_companies
movies_df.head()
# Out:
#    adult    budget                                             genres     id  \
# 0  False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2  False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4  False         0                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#   original_language popularity                    production_companies  \
# 0                en    21.9469                 Pixar Animation Studios
# 1                en    17.0155                        TriStar Pictures
# 2                en    11.7129                            Warner Bros.
# 3                en    3.85949  Twentieth Century Fox Film Corporation
# 4                en    8.38752                   Sandollar Productions
#
#        production_countries release_date      revenue  runtime  \
# 0  United States of America   1995-10-30  373554033.0     81.0
# 1  United States of America   1995-12-15  262797249.0    104.0
# 2  United States of America   1995-12-22          0.0    101.0
# 3  United States of America   1995-12-22   81452156.0    127.0
# 4  United States of America   1995-02-10   76578911.0    106.0
#
#                          title  vote_average  vote_count
# 0                    Toy Story           7.7      5415.0
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0

# %%
movies_df['release_date'] = [str(release_date).split('-')[0] for release_date in movies_df['release_date']]

# %%
movie_genres = []
for genres in movies_df['genres']:
    movie_genres.append([genre['name'] for genre in literal_eval(genres)])
movies_df['genres'] = movie_genres

# %%
credits_df = pd.read_csv('Data/credits.csv')

# %%
main_actor = []
main_actor_gender = []

for cast in credits_df['cast']:
    try:
        main_actor.append(literal_eval(cast)[0]['name'])
        main_actor_gender.append(literal_eval(cast)[0]['gender'])
    except:
        main_actor.append(None)
        main_actor_gender.append(None)
credits_df['main_actor'] = main_actor
credits_df['main_actor_gender'] = main_actor_gender

# %%
director = []
director_gender = []

for crew in credits_df['crew']:
    try:
        director.append(literal_eval(crew)[0]['name'])
        director_gender.append(literal_eval(crew)[0]['gender'])
    except:
        director.append(None)
        director_gender.append(None)
credits_df['director'] = director
credits_df['director_gender'] = director_gender

# %%
movies_df.head()
# Out:
#    adult    budget                        genres     id original_language  \
# 0  False  30000000   [Animation, Comedy, Family]    862                en
# 1  False  65000000  [Adventure, Fantasy, Family]   8844                en
# 2  False         0             [Romance, Comedy]  15602                en
# 3  False  16000000      [Comedy, Drama, Romance]  31357                en
# 4  False         0                      [Comedy]  11862                en
#
#   popularity                    production_companies  \
# 0    21.9469                 Pixar Animation Studios
# 1    17.0155                        TriStar Pictures
# 2    11.7129                            Warner Bros.
# 3    3.85949  Twentieth Century Fox Film Corporation
# 4    8.38752                   Sandollar Productions
#
#        production_countries release_date      revenue  runtime  \
# 0  United States of America         1995  373554033.0     81.0
# 1  United States of America         1995  262797249.0    104.0
# 2  United States of America         1995          0.0    101.0
# 3  United States of America         1995   81452156.0    127.0
# 4  United States of America         1995   76578911.0    106.0
#
#                          title  vote_average  vote_count
# 0                    Toy Story           7.7      5415.0
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0

# %%
credits_df.drop(columns=['cast', 'crew'], inplace = True)

# %%
credits_df.head()
# Out:
#       id       main_actor  main_actor_gender         director  director_gender
# 0    862        Tom Hanks                2.0    John Lasseter              2.0
# 1   8844   Robin Williams                2.0  Larry J. Franco              2.0
# 2  15602   Walter Matthau                2.0    Howard Deutch              2.0
# 3  31357  Whitney Houston                1.0  Forest Whitaker              2.0
# 4  11862     Steve Martin                2.0   Alan Silvestri              2.0

# %%
ratings_df.drop(columns=['timestamp'], inplace = True)

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %%
movies_df.id = movies_df.id.convert_objects(convert_numeric=True)
df_combined = pd.merge(ratings_df, movies_df, left_on='movieId', right_on='id', how='left')
# Out:
# C:\Users\sinth\anaconda3\envs\pyvizenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use Series.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
df_combined.head()
# Out:
#    userId  movieId  rating adult budget genres  id original_language  \
# 0       1       31     2.5   NaN    NaN    NaN NaN               NaN
# 1       1     1029     3.0   NaN    NaN    NaN NaN               NaN
# 2       1     1061     3.0   NaN    NaN    NaN NaN               NaN
# 3       1     1129     2.0   NaN    NaN    NaN NaN               NaN
# 4       1     1172     4.0   NaN    NaN    NaN NaN               NaN
#
#   popularity production_companies production_countries release_date  revenue  \
# 0        NaN                  NaN                  NaN          NaN      NaN
# 1        NaN                  NaN                  NaN          NaN      NaN
# 2        NaN                  NaN                  NaN          NaN      NaN
# 3        NaN                  NaN                  NaN          NaN      NaN
# 4        NaN                  NaN                  NaN          NaN      NaN
#
#    runtime title  vote_average  vote_count
# 0      NaN   NaN           NaN         NaN
# 1      NaN   NaN           NaN         NaN
# 2      NaN   NaN           NaN         NaN
# 3      NaN   NaN           NaN         NaN
# 4      NaN   NaN           NaN         NaN

# %%
ratings_df.shape
# Out:
# (100004, 3)

# %%
movies_df.shape
# Out:
# (45466, 14)

# %%
df_combined.shape
# Out:
# (100009, 17)

# %%
df_combined.drop(columns=['id'], inplace = True)

# %%
df_combined = pd.merge(df_combined, credits_df, left_on='movieId', right_on='id', how='left')

# %%
df_combined.drop(columns=['id'], inplace = True)

# %%
df_combined.dropna(inplace = True)

# %%
df_combined.head()
# Out:
#     userId  movieId  rating  adult    budget                    genres  \
# 10       1     1371     2.5  False  17000000                   [Drama]
# 11       1     1405     1.0  False    546883          [Drama, History]
# 13       1     2105     4.0  False  11000000         [Comedy, Romance]
# 15       1     2193     2.0  False         0  [Comedy, Drama, Romance]
# 16       1     2294     2.0  False  22000000                  [Comedy]
#
#    original_language popularity          production_companies  \
# 10                en    11.6734                United Artists
# 11                en    6.92508     Metro-Goldwyn-Mayer (MGM)
# 13                en    18.3442            Universal Pictures
# 15                en    4.67546  Crown International Pictures
# 16                en    11.6194               Dimension Films
#
#         production_countries release_date      revenue  runtime  \
# 10  United States of America         1982  270000000.0     99.0
# 11  United States of America         1924          0.0    140.0
# 13  United States of America         1999  235483004.0     95.0
# 15  United States of America         1983   22587000.0     97.0
# 16  United States of America         2001   33788161.0    104.0
#
#                              title  vote_average  vote_count  \
# 10                       Rocky III           6.6       894.0
# 11                           Greed           7.5        25.0
# 13                    American Pie           6.4      2358.0
# 15                        My Tutor           5.8        17.0
# 16  Jay and Silent Bob Strike Back           6.4       491.0
#
#             main_actor  main_actor_gender            director  director_gender
# 10  Sylvester Stallone                2.0  Sylvester Stallone              2.0
# 11          Zasu Pitts                1.0     Irving Thalberg              2.0
# 13         Jason Biggs                2.0        Chris Bender              2.0
# 15          Caren Kaye                1.0         Mac Ahlberg              2.0
# 16         Kevin Smith                2.0       Bob Weinstein              2.0

# %%
import numpy as np
movie_rating_matrix = pd.pivot_table(df_combined, values='rating', index='userId',
                                    columns=['title'], aggfunc=np.sum)

# %%
movie_rating_matrix.head()
# Out:
# title   'Gator Bait  'Twas the Night Before Christmas  \
# userId
# 1               NaN                               NaN
# 2               NaN                               NaN
# 3               NaN                               NaN
# 4               NaN                               NaN
# 5               NaN                               NaN
#
# title   ...And God Created Woman  00 Schneider - Jagd auf Nihil Baxter  \
# userId
# 1                            NaN                                   NaN
# 2                            NaN                                   NaN
# 3                            NaN                                   NaN
# 4                            NaN                                   NaN
# 5                            NaN                                   NaN
#
# title   10 Items or Less  10 Things I Hate About You  10,000 BC  \
# userId
# 1                    NaN                         NaN        NaN
# 2                    NaN                         NaN        NaN
# 3                    NaN                         NaN        NaN
# 4                    NaN                         NaN        NaN
# 5                    NaN                         NaN        NaN
#
# title   11'09''01 - September 11  12 Angry Men  13 Tzameti  ...  Zodiac  \
# userId                                                      ...
# 1                            NaN           NaN         NaN  ...     NaN
# 2                            NaN           NaN         NaN  ...     NaN
# 3                            NaN           NaN         NaN  ...     NaN
# 4                            NaN           NaN         NaN  ...     NaN
# 5                            NaN           NaN         NaN  ...     NaN
#
# title   Zombie Flesh Eaters  Zombie Holocaust  Zozo  eXistenZ  xXx  \
# userId
# 1                       NaN               NaN   NaN       NaN  NaN
# 2                       NaN               NaN   NaN       NaN  NaN
# 3                       NaN               NaN   NaN       NaN  NaN
# 4                       NaN               NaN   NaN       NaN  NaN
# 5                       NaN               NaN   NaN       NaN  NaN
#
# title   ¡Three Amigos!  À nos amours  Ödipussi  Şaban Oğlu Şaban
# userId
# 1                  NaN           NaN       NaN               NaN
# 2                  NaN           NaN       NaN               NaN
# 3                  NaN           NaN       NaN               NaN
# 4                  NaN           NaN       NaN               NaN
# 5                  NaN           NaN       NaN               NaN
#
# [5 rows x 2472 columns]

# %%
def movieRecomender(movie_title, criteria, value, df_combined):
    movie_corr = movie_rating_matrix.corrwith(movie_rating_matrix[movie_title])
    df_combined
# Out:
# C:\Users\sinth\anaconda3\envs\pyvizenv\lib\site-packages\numpy\lib\function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\sinth\anaconda3\envs\pyvizenv\lib\site-packages\numpy\lib\function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# title
# 'Gator Bait                                  NaN
# 'Twas the Night Before Christmas             NaN
# ...And God Created Woman                     NaN
# 00 Schneider - Jagd auf Nihil Baxter         NaN
# 10 Items or Less                       -1.000000
# 10 Things I Hate About You             -1.000000
# 10,000 BC                                    NaN
# 11'09''01 - September 11                     NaN
# 12 Angry Men                                 NaN
# 13 Tzameti                                   NaN
# 1408                                         NaN
# 15 Minutes                                   NaN
# 16 Blocks                                    NaN
# 1900                                         NaN
# 1942: A Love Story                           NaN
# 1984                                   -0.188982
# 2 Days in Paris                              NaN
# 20,000 Leagues Under the Sea            0.428845
# 2001: A Space Odyssey                   0.292883
# 2010                                         NaN
# 2046                                         NaN
# 2061 - Un anno eccezionale                   NaN
# 21 Grams                                     NaN
# 24 Hour Party People                    0.525885
# 25th Hour                               0.878310
# 28 Days Later                          -0.285192
# 28 Weeks Later                          0.448726
# 2:37                                    1.000000
# 3 Ninjas: High Noon at Mega Mountain         NaN
# 3-Iron                                       NaN
#                                           ...
# Yella                                   0.400877
# Yesterday                               0.085280
# You Instead                                  NaN
# You Only Live Twice                          NaN
# You're a Big Boy Now                         NaN
# You, Me and Dupree                           NaN
# Young Adam                              0.336358
# Young Black Stallion                         NaN
# Young Frankenstein                      0.626412
# Young Mr. Lincoln                            NaN
# Young and Innocent                     -0.283284
# Young, Violent, Dangerous                    NaN
# Z                                            NaN
# Zaat                                         NaN
# Zabriskie Point                              NaN
# Zapped Again!                                NaN
# Zardoz                                       NaN
# Zatoichi                               -0.111751
# Zatôichi's Pilgrimage                        NaN
# Zazie dans le métro                          NaN
# Zodiac                                  0.821720
# Zombie Flesh Eaters                          NaN
# Zombie Holocaust                             NaN
# Zozo                                         NaN
# eXistenZ                                     NaN
# xXx                                     0.628971
# ¡Three Amigos!                               NaN
# À nos amours                           -0.812605
# Ödipussi                                     NaN
# Şaban Oğlu Şaban                             NaN
# Length: 2472, dtype: float64
